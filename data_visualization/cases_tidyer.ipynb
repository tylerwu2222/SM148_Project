# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt

# %%
messy = pd.read_csv('time_series_covid19_confirmed_US.csv')
messy.drop(messy.iloc[:, :5], inplace = True,axis=1)
messy.drop(messy.iloc[:, 2:6], inplace = True,axis=1)
messy.head()
# Out:
#     Admin2 Province_State  1/22/2020  1/23/2020  1/24/2020  1/25/2020  \
# 0  Autauga        Alabama          0          0          0          0
# 1  Baldwin        Alabama          0          0          0          0
# 2  Barbour        Alabama          0          0          0          0
# 3     Bibb        Alabama          0          0          0          0
# 4   Blount        Alabama          0          0          0          0
#
#    1/26/2020  1/27/2020  1/28/2020  1/29/2020  ...  1/16/2022  1/17/2022  \
# 0          0          0          0          0  ...      12624      12682
# 1          0          0          0          0  ...      46528      46893
# 2          0          0          0          0  ...       4684       4713
# 3          0          0          0          0  ...       5274       5302
# 4          0          0          0          0  ...      12520      12579
#
#    1/18/2022  1/19/2022  1/20/2022  1/21/2022  1/22/2022  1/23/2022  \
# ...

# %%
tidy = pd.melt(messy,id_vars = ['Admin2','Province_State'],var_name = 'date',value_name='cases')
tidy.head()
tidy.to_csv('time_series_covid19_confirmed_tidy.csv',index=False)

# %%
Autauga = tidy.loc[tidy.Admin2 == 'Autauga']
plt.plot(Autauga.date,Autauga.cases)
